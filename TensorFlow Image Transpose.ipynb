# %%
import tensorflow as tf
import matplotlib.image as mp_img
import matplotlib.pyplot as plot
import os

#/images/dog-cute-pet.jpg
filename = "./images/dog-cute-pet.jpg"

image = mp_img.imread(filename)

print ("Image shape: ", image.shape)
print ("Image array: ", image)

plot.imshow(image)
plot.show()

x = tf.Variable(image, name='x')

init = tf.global_variables_initializer()

with tf.Session() as sess:
	sess.run(init)

	transpose = tf.image.transpose_image(x)

	result = sess.run(transpose)

	print ("Transposed image shape: ", result.shape)
	plot.imshow(result)
	plot.show()
# Out:
# Image shape:  (183, 275, 3)
# Image array:  [[[240 236 224]
#   [240 236 224]
#   [239 235 223]
#   ...
#   [229 230 199]
#   [228 229 198]
#   [228 229 198]]
#
#  [[240 236 224]
#   [240 236 224]
#   [240 236 224]
#   ...
#   [227 228 196]
#   [227 228 196]
#   [226 227 195]]
#
#  [[240 236 224]
#   [240 236 224]
#   [240 236 224]
#   ...
#   [224 225 191]
#   [224 225 191]
#   [224 225 191]]
#
#  ...
#
#  [[ 70  50  39]
#   [ 65  45  34]
#   [ 61  41  30]
#   ...
#   [ 68  40  28]
#   [ 67  39  27]
#   [ 67  39  27]]
#
#  [[ 66  46  35]
#   [ 64  44  33]
#   [ 62  42  31]
#   ...
#   [ 79  51  39]
#   [ 78  50  38]
#   [ 78  50  38]]
#
#  [[ 55  35  24]
#   [ 57  37  26]
#   [ 58  38  27]
#   ...
#   [ 65  39  26]
#   [ 65  39  26]
#   [ 65  39  26]]]
# Transposed image shape:  (275, 183, 3)
